# %% [markdown]
# Github URL:
# https://github.com/Spring-2025-14825-GenAI/hw-1-tokenization-and-llm-application-design-nick1117

# %% [markdown]
# # **Q1**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # **Q2**

# %% [markdown]
# In GCP, go to vertex AI, go to workbench, create an instance, create a user manage notebook and open jupyter notebook, Impliment the code below

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-xl")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-xl", device_map="auto")

# %%
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/Great_Hurricane_of_1780"
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")
body_content = soup.find("div", {"id": "bodyContent"})
input_text = body_content.get_text(strip=True)

encoded_text = tokenizer.encode(input_text)
tokens = tokenizer.convert_ids_to_tokens(encoded_text)
print(f"Total number of tokens: {len(tokens)}")
print(f"First 5 tokens: {tokens[:5]}")

# %% [markdown]
# Output:
#
# Total number of tokens: 4620
# First 5 tokens: ['▁From', '▁Wikipedia', ',', '▁the', '▁free']

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # **Q3**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# # **Q4**

# %% [markdown]
# ![image.png](attachment:image.png)
